# %%
import yfinance as yf
import pandas as pd
import numpy as np
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.stattools import adfuller  # ADF test for stationarity
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima  # For automated ARIMA parameter tuning
import matplotlib.pyplot as plt

# List of tickers for the six companies
tickers = ["LLY", "ABBV", "JNJ", "MRK", "TMO", "UNH"]
# tickers = ["AAPL", "MSFT", "GOOG", "AMZN", "META", "NVDA"]

# Define the start and end dates
start_date = '2014-09-01'
end_date = '2024-09-01'

# Define the folder path for saving CSV files
data_folder = os.path.join(os.getcwd(), 'data')

# Create the folder if it doesn't exist
if not os.path.exists(data_folder):
    os.makedirs(data_folder)


# Function to check stationarity using ADF test and apply differencing until stationarity or max differencing
def make_stationary(series, name="", max_diff_order=3):
    differencing_order = 0  # Track the number of differencing steps applied

    while differencing_order <= max_diff_order:
        # Perform the ADF test
        adf_result = adfuller(series)
        print(f"ADF Test Statistic for {name} (Differencing Order: {differencing_order}): {adf_result[0]}")
        print(f"ADF p-value for {name} (Differencing Order: {differencing_order}): {adf_result[1]}")

        # Check if the series is stationary
        if adf_result[1] <= 0.05:
            print(f"The series '{name}' is stationary (p <= 0.05) at differencing order {differencing_order}.")
            return series  # Return the stationary series
        elif differencing_order == max_diff_order:
            print(f"Reached max differencing order for '{name}'. Proceeding with current differencing.")
            return series  # Return the current differenced series even if not stationary
        else:
            # If not stationary, apply further differencing
            print(f"The series '{name}' is NOT stationary (p > 0.05), applying another differencing.")
            series = series.diff().dropna()  # Apply differencing and remove NaN values
            differencing_order += 1  # Increment differencing order


# Initialize lists to store RMSE and MAE for each ticker
mae_list = []
rmse_list = []

# For each ticker, process data
for ticker in tickers:
    print(f"\nProcessing data for {ticker}...")

    # Download historical stock data
    hist = yf.download(ticker, start=start_date, end=end_date)

    # Save the raw data to CSV
    raw_csv_filename = os.path.join(data_folder, f"{ticker}_raw_data.csv")
    hist.to_csv(raw_csv_filename)
    print(f"Raw data for {ticker} saved to '{raw_csv_filename}'")

    # Ensure index is a DateTimeIndex and set frequency
    hist.index = pd.to_datetime(hist.index)
    hist = hist.asfreq('B')  # Set frequency to Business Days ('B')
    hist.ffill(inplace=True)  # Fill missing values

    # Apply stationarity check and differencing to exogenous variables
    hist['Open_stationary'] = make_stationary(hist['Open'], name="Open")
    hist['Low_stationary'] = make_stationary(hist['Low'], name="Low")
    hist['High_stationary'] = make_stationary(hist['High'], name="High")
    hist['Adj_Close_stationary'] = make_stationary(hist['Adj Close'], name="Adj Close")

    # Generate lagged versions of exogenous variables
    hist['Open_stationary_lag1'] = hist['Open_stationary'].shift(1)
    hist['Low_stationary_lag1'] = hist['Low_stationary'].shift(1)
    hist['High_stationary_lag1'] = hist['High_stationary'].shift(1)
    hist['Adj_Close_stationary_lag1'] = hist['Adj_Close_stationary'].shift(1)

    # Drop rows with NaN values created by differencing and lagging
    hist.dropna(inplace=True)

    # Train-test split (80% train, 20% test)
    split_point = int(len(hist) * 0.8)
    train_data = hist[:split_point]
    test_data = hist[split_point:]

    # Define the endogenous variable (raw Close price) and exogenous (lagged stationary variables)
    endog_train = train_data['Close']  # Use the raw Close prices
    exog_train = train_data[['Open_stationary_lag1', 'Low_stationary_lag1', 'High_stationary_lag1', 'Adj_Close_stationary_lag1']]
    endog_test = test_data['Close']  # Use the raw Close prices for testing
    exog_test = test_data[['Open_stationary_lag1', 'Low_stationary_lag1', 'High_stationary_lag1', 'Adj_Close_stationary_lag1']]

    # Auto ARIMA parameter tuning for each ticker
    print(f"Finding optimal ARIMA parameters for {ticker} using auto_arima...")
    auto_arima_model = auto_arima(endog_train, exogenous=exog_train, seasonal=False, trace=True, error_action='ignore', suppress_warnings=True)
    best_order = auto_arima_model.order
    print(f"Optimal ARIMA order for {ticker}: {best_order}")

    # Fit ARIMAX model with tuned parameters
    print(f"Fitting ARIMAX model for {ticker} with order {best_order}...")
    try:
        model = ARIMA(endog_train, order=best_order, exog=exog_train)
        arimax_result = model.fit()  # Fit without maxiter to rely on default optimizer settings
    except (ValueError, np.linalg.LinAlgError, RuntimeError) as e:
        print(f"Error fitting ARIMAX model for {ticker} with order {best_order}: {e}. Trying a simpler model order.")
        try:
            # If error occurs, fallback to a simpler ARIMA order, e.g., (1,1,1)
            simpler_order = (1, 1, 1)
            model = ARIMA(endog_train, order=simpler_order, exog=exog_train)
            arimax_result = model.fit()  # Use the simpler model without maxiter
            print(f"Simpler ARIMA model with order {simpler_order} fitted for {ticker}.")
        except Exception as final_e:
            print(f"Failed to fit ARIMAX model for {ticker} even with simpler order: {final_e}")
            continue  # Skip this ticker if all fitting attempts fail

    # Forecast using the ARIMAX model
    forecast = arimax_result.forecast(steps=len(endog_test), exog=exog_test)

    # Plot actual vs forecasted values (in original 'Close' scale)
    plt.figure(figsize=(10, 6))
    plt.plot(endog_test.index, test_data['Close'], label='Actual Close Prices', color='blue')
    plt.plot(endog_test.index, forecast, label='Forecasted Close Prices', color='red')
    plt.title(f'ARIMAX Forecast vs Actual for {ticker}')
    plt.legend()
    plt.show()

    # Calculate MAE and RMSE directly since no inversion is required
    mae = mean_absolute_error(test_data['Close'], forecast)
    rmse = np.sqrt(mean_squared_error(test_data['Close'], forecast))
    print(f"Mean Absolute Error (MAE) for {ticker}: {mae}")
    print(f"Root Mean Squared Error (RMSE) for {ticker}: {rmse}")

    # Store the MAE and RMSE in the respective lists
    mae_list.append(mae)
    rmse_list.append(rmse)

    # Plot the residuals to check the fit
    residuals = arimax_result.resid
    plt.figure(figsize=(10, 6))
    plt.plot(residuals)
    plt.title(f'Residuals of ARIMAX model for {ticker}')
    plt.show()

    # Plot the autocorrelation function (ACF) of residuals
    print(f"Plotting ACF of residuals for {ticker}...")
    plot_acf(residuals, lags=40)
    plt.title(f'Autocorrelation of Residuals for {ticker}')
    plt.show()

print("Data processing, ADF testing, differencing, lagging, ARIMAX modeling with auto-tuning, and residual analysis completed.")

# Calculate the average MAE and RMSE
average_mae = np.mean(mae_list)
average_rmse = np.mean(rmse_list)

# Display the final average MAE and RMSE
print(f"\nFinal Average MAE for all tickers: {average_mae}")
print(f"Final Average RMSE for all tickers: {average_rmse}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Processing data for AAPL...
# Raw data for AAPL saved to 'c:\Users\brian\OneDrive\Documents\NUS\Y4S1\DSE4212_QF4212\Project\data\AAPL_raw_data.csv'
# ADF Test Statistic for Open (Differencing Order: 0): 0.6872862701158348
# ADF p-value for Open (Differencing Order: 0): 0.9895807001577053
# The series 'Open' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Open (Differencing Order: 1): -31.435757868083314
# ADF p-value for Open (Differencing Order: 1): 0.0
# The series 'Open' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for Low (Differencing Order: 0): 0.5433121745499547
# ADF p-value for Low (Differencing Order: 0): 0.9861317500213036
# The series 'Low' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Low (Differencing Order: 1): -24.866522175728914
# ADF p-value for Low (Differencing Order: 1): 0.0
# The series 'Low' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for High (Differencing Order: 0): 0.5609869345044588
# ADF p-value for High (Differencing Order: 0): 0.9866134899843712
# The series 'High' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for High (Differencing Order: 1): -21.593000532888336
# ADF p-value for High (Differencing Order: 1): 0.0
# The series 'High' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for Adj Close (Differencing Order: 0): 0.7006191514372719
# ADF p-value for Adj Close (Differencing Order: 0): 0.9898502177281705
# The series 'Adj Close' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Adj Close (Differencing Order: 1): -16.203208776515048
# ADF p-value for Adj Close (Differencing Order: 1): 4.05715662569705e-29
# The series 'Adj Close' is stationary (p <= 0.05) at differencing order 1.
# Finding optimal ARIMA parameters for AAPL using auto_arima...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=7853.225, Time=0.99 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7862.167, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7856.608, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=7856.288, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=7863.488, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=7859.536, Time=0.53 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=7859.491, Time=0.36 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.40 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=7855.319, Time=0.56 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=7857.635, Time=0.27 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=7858.671, Time=0.50 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=7858.109, Time=0.61 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.67 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=7854.872, Time=0.32 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 7.519 seconds
# Optimal ARIMA order for AAPL: (2, 1, 2)
# Fitting ARIMAX model for AAPL with order (2, 1, 2)...
# Mean Absolute Error (MAE) for AAPL: 24.82131021805145
# Root Mean Squared Error (RMSE) for AAPL: 30.32255862219802
# Plotting ACF of residuals for AAPL...
# [*********************100%***********************]  1 of 1 completed
# Processing data for MSFT...
# Raw data for MSFT saved to 'c:\Users\brian\OneDrive\Documents\NUS\Y4S1\DSE4212_QF4212\Project\data\MSFT_raw_data.csv'
# ADF Test Statistic for Open (Differencing Order: 0): 0.5278924650419695
# ADF p-value for Open (Differencing Order: 0): 0.9856966575423022
# The series 'Open' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Open (Differencing Order: 1): -26.040150528734515
# ADF p-value for Open (Differencing Order: 1): 0.0
# The series 'Open' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for Low (Differencing Order: 0): 0.5261767426040893
# ADF p-value for Low (Differencing Order: 0): 0.985647372068074
# The series 'Low' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Low (Differencing Order: 1): -38.574148322194915
# ADF p-value for Low (Differencing Order: 1): 0.0
# The series 'Low' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for High (Differencing Order: 0): 0.5313911866665967
# ADF p-value for High (Differencing Order: 0): 0.985796614692052
# The series 'High' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for High (Differencing Order: 1): -15.931202373414497
# ADF p-value for High (Differencing Order: 1): 7.725910093589089e-29
# The series 'High' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for Adj Close (Differencing Order: 0): 1.0295594070636978
# ADF p-value for Adj Close (Differencing Order: 0): 0.9945682474666904
# The series 'Adj Close' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Adj Close (Differencing Order: 1): -11.534547019185352
# ADF p-value for Adj Close (Differencing Order: 1): 3.7609572459439405e-21
# The series 'Adj Close' is stationary (p <= 0.05) at differencing order 1.
# Finding optimal ARIMA parameters for MSFT using auto_arima...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=10253.940, Time=0.40 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=10296.860, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=10248.001, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=10249.708, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=10297.602, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=10249.941, Time=0.15 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=10249.941, Time=0.17 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=10251.941, Time=0.23 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=10249.749, Time=0.06 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0] intercept
# Total fit time: 1.320 seconds
# Optimal ARIMA order for MSFT: (1, 1, 0)
# Fitting ARIMAX model for MSFT with order (1, 1, 0)...
# Mean Absolute Error (MAE) for MSFT: 84.21535306903567
# Root Mean Squared Error (RMSE) for MSFT: 102.75325918707688
# Plotting ACF of residuals for MSFT...
# [*********************100%***********************]  1 of 1 completed
# Processing data for GOOG...
# Raw data for GOOG saved to 'c:\Users\brian\OneDrive\Documents\NUS\Y4S1\DSE4212_QF4212\Project\data\GOOG_raw_data.csv'
# ADF Test Statistic for Open (Differencing Order: 0): -0.12600344348961462
# ADF p-value for Open (Differencing Order: 0): 0.9467861032107524
# The series 'Open' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Open (Differencing Order: 1): -54.326592186018566
# ADF p-value for Open (Differencing Order: 1): 0.0
# The series 'Open' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for Low (Differencing Order: 0): 0.04316802407829277
# ADF p-value for Low (Differencing Order: 0): 0.9619597505659131
# The series 'Low' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Low (Differencing Order: 1): -24.984360259861102
# ADF p-value for Low (Differencing Order: 1): 0.0
# The series 'Low' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for High (Differencing Order: 0): 0.010444917020613077
# ADF p-value for High (Differencing Order: 0): 0.9593873966115495
# The series 'High' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for High (Differencing Order: 1): -17.140648420620895
# ADF p-value for High (Differencing Order: 1): 7.048701086387721e-30
# The series 'High' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for Adj Close (Differencing Order: 0): 0.0845164702679613
# ADF p-value for Adj Close (Differencing Order: 0): 0.9649879232057949
# The series 'Adj Close' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Adj Close (Differencing Order: 1): -13.781526574602687
# ADF p-value for Adj Close (Differencing Order: 1): 9.277034222012115e-26
# The series 'Adj Close' is stationary (p <= 0.05) at differencing order 1.
# Finding optimal ARIMA parameters for GOOG using auto_arima...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=7011.100, Time=1.40 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7026.443, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7016.499, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=7017.173, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=7026.253, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=7013.535, Time=0.34 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=7013.571, Time=0.42 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=7008.925, Time=0.73 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=7010.495, Time=0.45 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=7010.837, Time=0.96 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.88 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=7008.602, Time=1.10 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=7008.972, Time=0.49 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=7010.150, Time=0.95 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=7010.970, Time=0.52 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=6978.920, Time=1.87 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=6973.258, Time=1.97 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=2.11 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=2.33 sec
#  ARIMA(4,1,5)(0,0,0)[0] intercept   : AIC=6971.684, Time=2.38 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=6977.496, Time=2.39 sec
#  ARIMA(5,1,5)(0,0,0)[0] intercept   : AIC=6975.186, Time=2.78 sec
#  ARIMA(4,1,5)(0,0,0)[0]             : AIC=6969.194, Time=1.57 sec
#  ARIMA(3,1,5)(0,0,0)[0]             : AIC=6977.851, Time=1.36 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : AIC=6969.605, Time=1.35 sec
#  ARIMA(5,1,5)(0,0,0)[0]             : AIC=6979.070, Time=2.05 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=6975.562, Time=1.18 sec
#  ARIMA(5,1,4)(0,0,0)[0]             : AIC=inf, Time=1.91 sec
#
# Best model:  ARIMA(4,1,5)(0,0,0)[0]
# Total fit time: 34.811 seconds
# Optimal ARIMA order for GOOG: (4, 1, 5)
# Fitting ARIMAX model for GOOG with order (4, 1, 5)...
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Mean Absolute Error (MAE) for GOOG: 28.071421015236865
# Root Mean Squared Error (RMSE) for GOOG: 34.81832960318526
# Plotting ACF of residuals for GOOG...
# [*********************100%***********************]  1 of 1 completed
# Processing data for AMZN...
# Raw data for AMZN saved to 'c:\Users\brian\OneDrive\Documents\NUS\Y4S1\DSE4212_QF4212\Project\data\AMZN_raw_data.csv'
# ADF Test Statistic for Open (Differencing Order: 0): -1.0246908860723138
# ADF p-value for Open (Differencing Order: 0): 0.744152693248353
# The series 'Open' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Open (Differencing Order: 1): -26.004461276661708
# ADF p-value for Open (Differencing Order: 1): 0.0
# The series 'Open' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for Low (Differencing Order: 0): -1.0205447883912468
# ADF p-value for Low (Differencing Order: 0): 0.745697507692949
# The series 'Low' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Low (Differencing Order: 1): -36.773588900091376
# ADF p-value for Low (Differencing Order: 1): 0.0
# The series 'Low' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for High (Differencing Order: 0): -0.9408068857416247
# ADF p-value for High (Differencing Order: 0): 0.7742373692362449
# The series 'High' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for High (Differencing Order: 1): -35.83046376796303
# ADF p-value for High (Differencing Order: 1): 0.0
# The series 'High' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for Adj Close (Differencing Order: 0): -0.88249980377566
# ADF p-value for Adj Close (Differencing Order: 0): 0.7936808431428632
# The series 'Adj Close' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Adj Close (Differencing Order: 1): -17.39570688468476
# ADF p-value for Adj Close (Differencing Order: 1): 4.97993061978902e-30
# The series 'Adj Close' is stationary (p <= 0.05) at differencing order 1.
# Finding optimal ARIMA parameters for AMZN using auto_arima...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=8914.400, Time=0.88 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=8929.928, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=8929.156, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=8929.255, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=8929.283, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=8927.117, Time=0.43 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=8927.214, Time=0.42 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=8914.366, Time=0.91 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=8924.898, Time=0.68 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=8915.999, Time=1.67 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=8916.014, Time=1.70 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=8914.295, Time=1.05 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=8923.953, Time=0.39 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=8915.991, Time=1.18 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=8924.455, Time=0.56 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=8916.793, Time=1.83 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=8913.736, Time=0.40 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=8923.484, Time=0.18 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=8907.362, Time=0.71 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=8926.492, Time=0.20 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=8926.595, Time=0.20 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=8913.800, Time=0.49 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=8925.235, Time=0.16 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=8924.423, Time=0.24 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=8915.502, Time=0.94 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 15.575 seconds
# Optimal ARIMA order for AMZN: (2, 1, 2)
# Fitting ARIMAX model for AMZN with order (2, 1, 2)...
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Mean Absolute Error (MAE) for AMZN: 28.64572787342124
# Root Mean Squared Error (RMSE) for AMZN: 34.72115960099654
# Plotting ACF of residuals for AMZN...
# [*********************100%***********************]  1 of 1 completed
# Processing data for META...
# Raw data for META saved to 'c:\Users\brian\OneDrive\Documents\NUS\Y4S1\DSE4212_QF4212\Project\data\META_raw_data.csv'
# ADF Test Statistic for Open (Differencing Order: 0): 0.06846385166124139
# ADF p-value for Open (Differencing Order: 0): 0.9638408378706146
# The series 'Open' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Open (Differencing Order: 1): -8.914424273063803
# ADF p-value for Open (Differencing Order: 1): 1.0823430600660967e-14
# The series 'Open' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for Low (Differencing Order: 0): 0.40054430566024424
# ADF p-value for Low (Differencing Order: 0): 0.9815152852522052
# The series 'Low' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Low (Differencing Order: 1): -17.006874417136114
# ADF p-value for Low (Differencing Order: 1): 8.64789301583597e-30
# The series 'Low' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for High (Differencing Order: 0): 0.341892888262727
# ADF p-value for High (Differencing Order: 0): 0.97918694811228
# The series 'High' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for High (Differencing Order: 1): -30.024969769296874
# ADF p-value for High (Differencing Order: 1): 0.0
# The series 'High' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for Adj Close (Differencing Order: 0): 0.5088647023300108
# ADF p-value for Adj Close (Differencing Order: 0): 0.9851400558484589
# The series 'Adj Close' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Adj Close (Differencing Order: 1): -14.399170240018623
# ADF p-value for Adj Close (Differencing Order: 1): 8.566104025105675e-27
# The series 'Adj Close' is stationary (p <= 0.05) at differencing order 1.
# Finding optimal ARIMA parameters for META using auto_arima...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=12219.028, Time=0.65 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=12224.219, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=12220.663, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=12220.835, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=12222.395, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=12220.723, Time=0.59 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=12221.636, Time=0.41 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=12214.013, Time=1.44 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=12212.878, Time=0.43 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=12215.906, Time=0.14 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=12214.874, Time=0.57 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=12221.997, Time=0.12 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=12216.163, Time=0.17 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=12216.843, Time=0.63 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=12211.137, Time=0.21 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=12219.822, Time=0.26 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=12214.117, Time=0.08 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=12213.133, Time=0.28 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=12212.259, Time=0.68 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=12220.185, Time=0.07 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=12217.274, Time=0.35 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=12214.387, Time=0.10 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=12215.101, Time=0.35 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0]
# Total fit time: 7.858 seconds
# Optimal ARIMA order for META: (3, 1, 1)
# Fitting ARIMAX model for META with order (3, 1, 1)...
# Mean Absolute Error (MAE) for META: 162.01136954459918
# Root Mean Squared Error (RMSE) for META: 201.2939775238501
# Plotting ACF of residuals for META...
# [*********************100%***********************]  1 of 1 completed
# Processing data for NVDA...
# Raw data for NVDA saved to 'c:\Users\brian\OneDrive\Documents\NUS\Y4S1\DSE4212_QF4212\Project\data\NVDA_raw_data.csv'
# ADF Test Statistic for Open (Differencing Order: 0): 3.297749944600153
# ADF p-value for Open (Differencing Order: 0): 1.0
# The series 'Open' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Open (Differencing Order: 1): -8.146601026720948
# ADF p-value for Open (Differencing Order: 1): 9.950301281940603e-13
# The series 'Open' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for Low (Differencing Order: 0): 2.774498715931019
# ADF p-value for Low (Differencing Order: 0): 1.0
# The series 'Low' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Low (Differencing Order: 1): -7.827589318511612
# ADF p-value for Low (Differencing Order: 1): 6.419747485885984e-12
# The series 'Low' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for High (Differencing Order: 0): 3.4417345009657656
# ADF p-value for High (Differencing Order: 0): 1.0
# The series 'High' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for High (Differencing Order: 1): -8.228944899837291
# ADF p-value for High (Differencing Order: 1): 6.137113885218029e-13
# The series 'High' is stationary (p <= 0.05) at differencing order 1.
# ADF Test Statistic for Adj Close (Differencing Order: 0): 2.932035613385369
# ADF p-value for Adj Close (Differencing Order: 0): 1.0
# The series 'Adj Close' is NOT stationary (p > 0.05), applying another differencing.
# ADF Test Statistic for Adj Close (Differencing Order: 1): -8.476696552222572
# ADF p-value for Adj Close (Differencing Order: 1): 1.4290371704800468e-13
# The series 'Adj Close' is stationary (p <= 0.05) at differencing order 1.
# Finding optimal ARIMA parameters for NVDA using auto_arima...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1561.203, Time=0.67 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1566.087, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1563.620, Time=0.24 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1563.095, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1564.911, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1559.534, Time=0.72 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1560.196, Time=0.20 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1563.492, Time=0.28 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1554.454, Time=1.04 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1557.994, Time=0.34 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=1556.424, Time=1.24 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=1556.436, Time=1.11 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=1558.508, Time=0.40 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=1553.566, Time=1.78 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=1556.008, Time=2.35 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=1555.493, Time=2.29 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=1557.824, Time=1.64 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=1557.061, Time=1.85 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=2.65 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=1552.258, Time=1.01 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=1555.130, Time=0.40 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=1555.117, Time=0.47 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=1554.692, Time=0.91 sec
#  ARIMA(2,1,5)(0,0,0)[0]             : AIC=1553.901, Time=1.16 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=1553.148, Time=0.33 sec
#  ARIMA(1,1,5)(0,0,0)[0]             : AIC=1559.543, Time=0.19 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=1555.745, Time=0.85 sec
#  ARIMA(3,1,5)(0,0,0)[0]             : AIC=inf, Time=1.46 sec
#
# Best model:  ARIMA(2,1,4)(0,0,0)[0]
# Total fit time: 26.004 seconds
# Optimal ARIMA order for NVDA: (2, 1, 4)
# Fitting ARIMAX model for NVDA with order (2, 1, 4)...
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Mean Absolute Error (MAE) for NVDA: 38.14708099245147
# Root Mean Squared Error (RMSE) for NVDA: 51.66007618423646
# Plotting ACF of residuals for NVDA...
# Data processing, ADF testing, differencing, lagging, ARIMAX modeling with auto-tuning, and residual analysis completed.
#
# Final Average MAE for all tickers: 60.98537711879931
# Final Average RMSE for all tickers: 75.92822678692387
