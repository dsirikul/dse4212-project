# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten, Dropout, MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# # Technology Stocks

# %%
# List of Stocks
stock_tickers = ['AAPL', 'AMZN', 'GOOG', 'META', 'MSFT', 'NVDA']

# Initialise List to store RMSE and MAE values
rmse_values = []
mae_values = []

# Loop through each stock ticker
for stock_ticker in stock_tickers:
    print(f'Processing {stock_ticker}...')

    # Load and preprocess data
    df = pd.read_csv(f'../data/{stock_ticker}_processed_data.csv', parse_dates=['Date'])
    df = df.dropna()
    features = ['Open', 'High', 'Low', 'Adj Close', 'Volume']
    X = df[features].shift(1).dropna()
    y = df['Close'][1:].dropna()

    df = df.iloc[1:]  # Drop the first row of the original DataFrame
    dates = df['Date'].dropna()  # Get the adjusted dates

    # Scale features and reshape for CNN input
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    y_scaled = scaler.fit_transform(y.values.reshape(-1, 1))
    X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))

    # Split data into training and testing sets (80% train, 20% test)
    split = int(0.8 * len(X_scaled))
    X_train, X_test = X_scaled[:split], X_scaled[split:]
    y_train, y_test = y_scaled[:split], y_scaled[split:]
    dates_train, dates_test = dates[:split], dates[split:]

    # Define the CNN model
    model = Sequential([
        Conv1D(64, kernel_size=2, activation='relu', input_shape=(len(features), 1)),
        MaxPooling1D(pool_size=2),
        Dropout(0.3),
        Flatten(),
        Dense(50, activation='relu'),
        Dropout(0.3),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse')

    # Train the model
    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

    # Predict and inverse transform
    predicted_prices = model.predict(X_test).flatten()
    cnn_pred_reshaped = np.zeros((len(predicted_prices), X.shape[1]))
    cnn_pred_reshaped[:, 3] = predicted_prices
    cnn_pred_prices = scaler.inverse_transform(cnn_pred_reshaped)[:, 3]

    y_test_reshaped = np.zeros((len(y_test), X.shape[1]))
    y_test_reshaped[:, 3] = y_test.flatten()
    actual_prices = scaler.inverse_transform(y_test_reshaped)[:, 3]

    plt.figure(figsize=(14, 8))
    plt.plot(dates_test, actual_prices, color='blue', label='Actual Prices')
    plt.plot(dates_test, cnn_pred_prices, color='red', label='Predicted Prices')
    plt.xlabel('Date')
    plt.ylabel('Stock Price')
    plt.title(f'{stock_ticker} Stock Price Prediction')

# Set y-ticks to increment by 50
    y_min = min(min(actual_prices), min(cnn_pred_prices))
    y_max = max(max(actual_prices), max(cnn_pred_prices))
    plt.yticks(range(int(y_min), int(y_max) + 50, 50))

    plt.legend()
    plt.show()

    # Calculate RMSE and MAE
    rmse = np.sqrt(mean_squared_error(actual_prices, cnn_pred_prices))
    mae = mean_absolute_error(actual_prices, cnn_pred_prices)
    print(f'{stock_ticker}_RMSE: {rmse}, {stock_ticker}_MAE: {mae}')

    # Append the results for later calculation
    rmse_values.append(rmse)
    mae_values.append(mae)

'''
    # Plot the predictions against actual prices
    plt.figure(figsize=(14, 8))
    plt.plot(dates_test, actual_prices, color='blue', label='Actual Prices')
    plt.plot(dates_test, cnn_pred_prices, color='red', label='Predicted Prices')
    plt.xlabel('Date')
    plt.ylabel('Stock Price')
    plt.title(f'{stock_ticker} Stock Price Prediction')
    plt.legend()
    plt.show()
'''    


# Calculating the mean RMSE and MAE across All stocks
mean_rmse = np.mean(rmse_values)
mean_mae = np.mean(mae_values)

print(f'Mean RMSE across Technology stocks: {mean_rmse}')
print(f'Mean MAE across Technology stocks: {mean_mae}')
# Out:
# Processing AAPL...
# Epoch 1/50
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0406 - val_loss: 0.0032
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - val_loss: 2.0513e-04
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - val_loss: 7.7713e-04
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 3.5934e-04
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 2.8171e-04
# Epoch 7/50
# ...

# %% [markdown]
# # Healthcare Stocks

# %%
# List of Stocks
stock_tickers = ['ABBV', 'JNJ', 'LLY', 'MRK', 'TMO', 'UNH']

# Initialise List to store RMSE and MAE values
rmse_values = []
mae_values = []

# Loop through each stock ticker
for stock_ticker in stock_tickers:
    print(f'Processing {stock_ticker}...')

    # Load and preprocess data
    df = pd.read_csv(f'../data/{stock_ticker}_processed_data.csv', parse_dates=['Date'])
    df = df.dropna()
    features = ['Open', 'High', 'Low', 'Adj Close', 'Volume']
    X = df[features].shift(1).dropna()
    y = df['Close'][1:].dropna()

    df = df.iloc[1:]  # Drop the first row of the original DataFrame
    dates = df['Date'].dropna()  # Get the adjusted dates

    # Scale features and reshape for CNN input
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    y_scaled = scaler.fit_transform(y.values.reshape(-1, 1))
    X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))

    # Split data into training and testing sets (80% train, 20% test)
    split = int(0.8 * len(X_scaled))
    X_train, X_test = X_scaled[:split], X_scaled[split:]
    y_train, y_test = y_scaled[:split], y_scaled[split:]
    dates_train, dates_test = dates[:split], dates[split:]

    # Define the CNN model
    model = Sequential([
        Conv1D(64, kernel_size=2, activation='relu', input_shape=(len(features), 1)),
        MaxPooling1D(pool_size=2),
        Dropout(0.3),
        Flatten(),
        Dense(50, activation='relu'),
        Dropout(0.3),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse')

    # Train the model
    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

    # Predict and inverse transform
    predicted_prices = model.predict(X_test).flatten()
    cnn_pred_reshaped = np.zeros((len(predicted_prices), X.shape[1]))
    cnn_pred_reshaped[:, 3] = predicted_prices
    cnn_pred_prices = scaler.inverse_transform(cnn_pred_reshaped)[:, 3]

    y_test_reshaped = np.zeros((len(y_test), X.shape[1]))
    y_test_reshaped[:, 3] = y_test.flatten()
    actual_prices = scaler.inverse_transform(y_test_reshaped)[:, 3]

    # Plot the predictions against actual prices
    plt.figure(figsize=(14, 8))
    plt.plot(dates_test, actual_prices, color='blue', label='Actual Prices')
    plt.plot(dates_test, cnn_pred_prices, color='red', label='Predicted Prices')
    plt.xlabel('Date')
    plt.ylabel('Stock Price')
    plt.title(f'{stock_ticker} Stock Price Prediction')

# Set y-ticks to increment by 50
    y_min = min(min(actual_prices), min(cnn_pred_prices))
    y_max = max(max(actual_prices), max(cnn_pred_prices))
    plt.yticks(range(int(y_min), int(y_max) + 50, 50))

    plt.legend()
    plt.show()

    # Calculate RMSE and MAE
    rmse = np.sqrt(mean_squared_error(actual_prices, cnn_pred_prices))
    mae = mean_absolute_error(actual_prices, cnn_pred_prices)
    print(f'{stock_ticker}_RMSE: {rmse}, {stock_ticker}_MAE: {mae}')

    # Append the results for later calculation
    rmse_values.append(rmse)
    mae_values.append(mae)

# Calculating the mean RMSE and MAE across All stocks
mean_rmse = np.mean(rmse_values)
mean_mae = np.mean(mae_values)

print(f'Mean RMSE across Healthcare stocks: {mean_rmse}')
print(f'Mean MAE across Healthcare stocks: {mean_mae}')
# Out:
# Processing ABBV...
# Epoch 1/50
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0239 - val_loss: 0.0031
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - val_loss: 0.0036
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - val_loss: 2.3433e-04
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 2.7038e-04
# Epoch 7/50
# ...
