# %%
import yfinance as yf
import pandas as pd
import numpy as np
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
import matplotlib.pyplot as plt
import pandas_ta as ta

# List of tickers for the six companies
tickers = ["LLY", "ABBV", "JNJ", "MRK", "TMO", "UNH"]
# tickers = ["AAPL", "MSFT", "GOOG", "AMZN", "META", "NVDA"]

# Define the start and end dates
start_date = '2014-09-01'
end_date = '2024-09-01'

# Define the folder path for saving CSV files
data_folder = os.path.join(os.getcwd(), 'data')

# Create the folder if it doesn't exist
if not os.path.exists(data_folder):
    os.makedirs(data_folder)


# Function to check stationarity using ADF test and apply differencing
def make_stationary(series, name="", max_diff_order=3):
    differencing_order = 0
    while differencing_order <= max_diff_order:
        adf_result = adfuller(series)
        if adf_result[1] <= 0.05:
            return series
        elif differencing_order == max_diff_order:
            return series
        else:
            series = series.diff().dropna()
            differencing_order += 1


# Initialize lists to store RMSE and MAE for each ticker
mae_list = []
rmse_list = []

# For each ticker, process data
for ticker in tickers:
    print(f"\nProcessing data for {ticker}...")

    # Download historical stock data
    hist = yf.download(ticker, start=start_date, end=end_date)

    # Save the raw data to CSV
    raw_csv_filename = os.path.join(data_folder, f"{ticker}_raw_data.csv")
    hist.to_csv(raw_csv_filename)

    # Ensure index is a DateTimeIndex and set frequency
    hist.index = pd.to_datetime(hist.index)
    hist = hist.asfreq('B')
    hist.ffill(inplace=True)

    # Additional Exogenous Variables
    hist['5_day_SMA'] = hist['Close'].rolling(window=5).mean()
    hist['20_day_SMA'] = hist['Close'].rolling(window=20).mean()
    hist['50_day_SMA'] = hist['Close'].rolling(window=50).mean()
    hist['14_day_RSI'] = ta.rsi(hist['Close'], window=14)
    hist['Lagged_Close'] = hist['Close'].shift(1)
    hist['ATR'] = ta.atr(hist['High'], hist['Low'], hist['Close'], window=14)
    hist['Day_of_Week'] = hist.index.dayofweek
    hist['Daily_Return'] = hist['Close'].pct_change()
    hist['Volatility'] = hist['Daily_Return'].rolling(window=5).std()

    # Handle NaN and Inf values in the newly created variables
    hist.replace([np.inf, -np.inf], np.nan, inplace=True)  # Replace Inf values with NaN
    hist.dropna(inplace=True)  # Drop rows with any NaN values

    # Apply stationarity check and differencing
    hist['Open_stationary'] = make_stationary(hist['Open'], name="Open")
    hist['Low_stationary'] = make_stationary(hist['Low'], name="Low")
    hist['High_stationary'] = make_stationary(hist['High'], name="High")
    hist['Adj_Close_stationary'] = make_stationary(hist['Adj Close'], name="Adj Close")
    hist['5_day_SMA_stationary'] = make_stationary(hist['5_day_SMA'], name="5_day_SMA")
    hist['20_day_SMA_stationary'] = make_stationary(hist['20_day_SMA'], name="20_day_SMA")
    hist['50_day_SMA_stationary'] = make_stationary(hist['50_day_SMA'], name="50_day_SMA")
    hist['14_day_RSI_stationary'] = make_stationary(hist['14_day_RSI'], name="14_day_RSI")
    hist['Lagged_Close_stationary'] = make_stationary(hist['Lagged_Close'], name="Lagged_Close")
    hist['ATR_stationary'] = make_stationary(hist['ATR'], name="ATR")
    hist['Daily_Return_stationary'] = make_stationary(hist['Daily_Return'], name="Daily_Return")
    hist['Volatility_stationary'] = make_stationary(hist['Volatility'], name="Volatility")

    # Generate lagged versions of exogenous variables
    exogenous_vars = ['Open_stationary', 'Low_stationary', 'High_stationary', 'Adj_Close_stationary',
                      '5_day_SMA_stationary', '20_day_SMA_stationary',
                      '50_day_SMA_stationary', '14_day_RSI_stationary', 'Lagged_Close_stationary', 'ATR_stationary',
                      'Daily_Return_stationary',
                      'Volatility_stationary', 'Day_of_Week']
    for var in exogenous_vars:
        hist[f"{var}_lag1"] = hist[var].shift(1)

    # Final dropna to ensure no NaN or Inf values remain
    hist.dropna(inplace=True)

    # Train-test split (80% train, 20% test)
    split_point = int(len(hist) * 0.8)
    train_data = hist[:split_point]
    test_data = hist[split_point:]

    # Define the endogenous and exogenous variables
    endog_train = train_data['Close']
    exog_train = train_data[[f"{var}_lag1" for var in exogenous_vars]]
    endog_test = test_data['Close']
    exog_test = test_data[[f"{var}_lag1" for var in exogenous_vars]]

    # Auto ARIMA parameter tuning for each ticker
    auto_arima_model = auto_arima(endog_train, exogenous=exog_train, seasonal=False, trace=True, error_action='ignore',
                                  suppress_warnings=True)
    best_order = auto_arima_model.order

    # Fit ARIMAX model with tuned parameters
    try:
        model = ARIMA(endog_train, order=best_order, exog=exog_train)
        arimax_result = model.fit()
    except (ValueError, np.linalg.LinAlgError, RuntimeError) as e:
        try:
            simpler_order = (1, 1, 1)
            model = ARIMA(endog_train, order=simpler_order, exog=exog_train)
            arimax_result = model.fit()
        except Exception as final_e:
            continue

    # Forecast
    forecast = arimax_result.forecast(steps=len(endog_test), exog=exog_test)

    # Plot actual vs forecasted values
    plt.figure(figsize=(10, 6))
    plt.plot(endog_test.index, test_data['Close'], label='Actual Close Prices', color='blue')
    plt.plot(endog_test.index, forecast, label='Forecasted Close Prices', color='red')
    plt.title(f'ARIMAX Forecast vs Actual for {ticker}')
    plt.legend()
    plt.show()

    # Calculate MAE and RMSE
    mae = mean_absolute_error(test_data['Close'], forecast)
    rmse = np.sqrt(mean_squared_error(test_data['Close'], forecast))
    print(f"Mean Absolute Error (MAE) for {ticker}: {mae}")
    print(f"Root Mean Squared Error (RMSE) for {ticker}: {rmse}")
    
    mae_list.append(mae)
    rmse_list.append(rmse)

    # Plot residuals and ACF of residuals
    residuals = arimax_result.resid
    plt.figure(figsize=(10, 6))
    plt.plot(residuals)
    plt.title(f'Residuals of ARIMAX model for {ticker}')
    plt.show()
    plot_acf(residuals, lags=40)
    plt.title(f'Autocorrelation of Residuals for {ticker}')
    plt.show()

# Calculate and display average MAE and RMSE
average_mae = np.mean(mae_list)
average_rmse = np.mean(rmse_list)
print(f"\nFinal Average MAE for all tickers: {average_mae}")
print(f"Final Average RMSE for all tickers: {average_rmse}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Processing data for AAPL...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=7796.668, Time=0.67 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7809.299, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7801.102, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=7800.601, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=7810.283, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=7803.720, Time=0.41 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=7803.651, Time=0.36 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=7799.382, Time=0.97 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=7800.834, Time=0.54 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=7801.856, Time=0.24 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=7803.989, Time=0.43 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=7803.209, Time=0.42 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=7799.894, Time=1.88 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=7797.978, Time=0.30 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 6.556 seconds
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [*********************100%***********************]  1 of 1 completed
# Processing data for MSFT...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=10136.465, Time=0.41 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=10177.549, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=10130.490, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=10131.892, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=10177.936, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=10132.468, Time=0.16 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=10132.467, Time=0.14 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=10134.482, Time=0.22 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=10131.737, Time=0.06 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0] intercept
# Total fit time: 1.315 seconds
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [*********************100%***********************]  1 of 1 completed
# Processing data for GOOG...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=6955.054, Time=1.34 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=6967.928, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=6957.104, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=6957.774, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=6967.639, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=6955.191, Time=0.32 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=6955.211, Time=0.46 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=6950.296, Time=0.77 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=6951.836, Time=0.20 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=6952.252, Time=1.08 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=6920.889, Time=2.05 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=6950.005, Time=0.80 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=6920.935, Time=2.10 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=6914.328, Time=2.04 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=6955.376, Time=0.40 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=2.22 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=6916.234, Time=2.48 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=6945.320, Time=2.01 sec
#  ARIMA(4,1,5)(0,0,0)[0] intercept   : AIC=6913.521, Time=2.62 sec
#  ARIMA(5,1,5)(0,0,0)[0] intercept   : AIC=6912.298, Time=2.86 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=6913.416, Time=2.47 sec
#  ARIMA(5,1,5)(0,0,0)[0]             : AIC=6912.645, Time=1.49 sec
#
# Best model:  ARIMA(5,1,5)(0,0,0)[0] intercept
# Total fit time: 28.049 seconds
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [*********************100%***********************]  1 of 1 completed
# Processing data for AMZN...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=8806.228, Time=3.11 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=8830.858, Time=0.19 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=8829.499, Time=0.28 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=8829.604, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=8830.281, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=8828.503, Time=0.94 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=8828.555, Time=1.06 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=8815.631, Time=2.02 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=8815.522, Time=1.95 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=8826.868, Time=0.90 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=8825.624, Time=1.15 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=8826.431, Time=1.11 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=8817.047, Time=5.21 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=8805.673, Time=0.61 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=8827.960, Time=0.20 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=8828.017, Time=0.23 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=8815.144, Time=0.51 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=8815.045, Time=0.44 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=8826.368, Time=0.17 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=8825.250, Time=0.23 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=8826.048, Time=0.34 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=8816.630, Time=1.04 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 22.221 seconds
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [*********************100%***********************]  1 of 1 completed
# Processing data for META...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=12041.141, Time=0.91 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=12045.813, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=12042.653, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=12042.783, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=12043.949, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=12042.359, Time=0.48 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=12044.000, Time=0.42 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=12036.931, Time=1.27 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=12034.937, Time=0.59 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=12037.809, Time=0.17 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=12036.936, Time=0.55 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=12044.191, Time=0.13 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=12037.980, Time=0.24 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=12038.909, Time=0.71 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=12033.149, Time=0.23 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=12042.144, Time=0.21 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=12035.979, Time=0.10 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=12035.147, Time=0.29 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=12035.143, Time=0.48 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=12042.337, Time=0.09 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=12039.341, Time=0.32 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=12036.162, Time=0.12 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=12037.121, Time=0.33 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0]
# Total fit time: 7.964 seconds
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [*********************100%***********************]  1 of 1 completed
# Processing data for NVDA...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1600.607, Time=0.88 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1604.385, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1602.689, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1602.266, Time=0.27 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1602.994, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1599.295, Time=0.61 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1599.649, Time=0.26 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1602.864, Time=0.53 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1593.480, Time=0.87 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1597.336, Time=0.33 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=1595.580, Time=0.87 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=1595.470, Time=1.17 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=1597.385, Time=0.37 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=1592.646, Time=1.88 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=1595.149, Time=2.46 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=1594.319, Time=2.17 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=1595.586, Time=1.77 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=1596.795, Time=1.92 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=1601.029, Time=2.89 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=1591.143, Time=1.05 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=1593.988, Time=0.53 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=1593.985, Time=0.56 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=1593.679, Time=1.14 sec
#  ARIMA(2,1,5)(0,0,0)[0]             : AIC=1592.838, Time=0.99 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=1591.997, Time=0.32 sec
#  ARIMA(1,1,5)(0,0,0)[0]             : AIC=1598.542, Time=0.21 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=1595.108, Time=0.93 sec
#  ARIMA(3,1,5)(0,0,0)[0]             : AIC=1598.974, Time=1.32 sec
#
# Best model:  ARIMA(2,1,4)(0,0,0)[0]
# Total fit time: 26.633 seconds
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Final Average MAE for all tickers: 67.33872562549267
# Final Average RMSE for all tickers: 95.11898956521675
