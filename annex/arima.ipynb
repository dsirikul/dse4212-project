# %%
import yfinance as yf
import pandas as pd
import numpy as np
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.stattools import adfuller  # ADF test for stationarity
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf  # For ACF and PACF plotting
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# List of tickers for the six companies
tickers = ["LLY", "ABBV", "JNJ", "MRK", "TMO", "UNH"]
# tickers = ["AAPL", "MSFT", "GOOG", "AMZN", "META", "NVDA"]

# Define the start and end dates
start_date = '2014-09-01'
end_date = '2024-09-01'

# Define the folder path for saving CSV files
data_folder = os.path.join(os.getcwd(), 'data')

# Create the folder if it doesn't exist
if not os.path.exists(data_folder):
    os.makedirs(data_folder)

# Function to check stationarity using ADF test
def check_stationarity(series, name=""):
    adf_result = adfuller(series)
    print(f"ADF Test Statistic for {name}: {adf_result[0]}")
    print(f"ADF p-value for {name}: {adf_result[1]}")
    if adf_result[1] <= 0.05:
        print(f"The series '{name}' is stationary (p <= 0.05).")
    else:
        print(f"The series '{name}' is NOT stationary (p > 0.05).")

# Initialize lists to store RMSE and MAE for each ticker
mae_list = []
rmse_list = []

for ticker in tickers:
    print(f"\nProcessing data for {ticker}...")

    # Download historical stock data using yf.download()
    hist = yf.download(ticker, start=start_date, end=end_date)

    # Save the raw data to a CSV file before any processing
    raw_csv_filename = os.path.join(data_folder, f"{ticker}_raw_data.csv")
    hist.to_csv(raw_csv_filename)
    print(f"Raw data for {ticker} saved to '{raw_csv_filename}'")

    # Ensure the index is a DateTimeIndex and set the frequency
    hist.index = pd.to_datetime(hist.index)  # Ensure the index is DateTimeIndex
    hist = hist.asfreq('B')  # Set frequency to Business Days ('B')

    # Fill any missing values caused by business day frequency adjustment
    hist.ffill(inplace=True)  # Forward fill to handle any missing dates

    # Check stationarity of the 'Close' prices
    print(f"\nChecking stationarity for {ticker} 'Close' prices:")
    check_stationarity(hist['Close'], name="Close")

    # Apply differencing to make the series stationary
    hist['Close_diff'] = hist['Close'].diff().dropna()  # First-order differencing

    # Check stationarity of the differenced 'Close' prices
    print(f"\nChecking stationarity for differenced {ticker} 'Close' prices:")
    check_stationarity(hist['Close_diff'].dropna(), name="Close_diff")

    # Plot ACF and PACF for the differenced series
    print(f"\nPlotting ACF and PACF for differenced {ticker} 'Close' prices...")
    plt.figure(figsize=(12, 6))

    # ACF Plot
    plt.subplot(121)
    plot_acf(hist['Close_diff'].dropna(), lags=40, ax=plt.gca())
    plt.title(f"ACF for {ticker} 'Close_diff'")

    # PACF Plot
    plt.subplot(122)
    plot_pacf(hist['Close_diff'].dropna(), lags=40, ax=plt.gca())
    plt.title(f"PACF for {ticker} 'Close_diff'")

    plt.tight_layout()
    plt.show()

    # Based on ACF/PACF plots, adjust p, d, q manually.
    # You can choose p, d, q based on the ACF/PACF plots and stationarity checks.
    p, d, q = 1, 1, 1  # Default (1, 1, 1); adjust based on ACF/PACF

    # Train-test split (80% train, 20% test)
    split_point = int(len(hist) * 0.8)
    train_data = hist['Close'][:split_point]
    test_data = hist['Close'][split_point:]

    # Fit ARIMA model (without exogenous variables, predicting based on past Close prices)
    print(f"Fitting ARIMA model for {ticker} with order ({p}, {d}, {q})...")
    model = ARIMA(train_data, order=(p, d, q))
    arima_result = model.fit()

    # Forecast the values for the test set
    forecast = arima_result.forecast(steps=len(test_data))

    # Plot actual vs forecasted values
    plt.figure(figsize=(10, 6))
    plt.plot(test_data.index, test_data, label='Actual Close Prices', color='blue')
    plt.plot(test_data.index, forecast, label='Forecasted Close Prices', color='red')
    plt.title(f'ARIMA Forecast vs Actual for {ticker}')
    plt.legend()
    plt.show()

    # Evaluate the model performance
    mae = mean_absolute_error(test_data, forecast)
    rmse = np.sqrt(mean_squared_error(test_data, forecast))
    print(f"Mean Absolute Error (MAE) for {ticker}: {mae}")
    print(f"Root Mean Squared Error (RMSE) for {ticker}: {rmse}")

    # Store the MAE and RMSE in the respective lists
    mae_list.append(mae)
    rmse_list.append(rmse)

    # Plot the residuals to check the fit
    residuals = arima_result.resid
    plt.figure(figsize=(10, 6))
    plt.plot(residuals)
    plt.title(f'Residuals of ARIMA model for {ticker}')
    plt.show()

    # Plot the autocorrelation function (ACF) of residuals
    print(f"Plotting ACF of residuals for {ticker}...")
    plot_acf(residuals, lags=40)
    plt.title(f'Autocorrelation of Residuals for {ticker}')
    plt.show()

print("Data processing, ADF testing, ACF/PACF plotting, ARIMA modeling, and residual analysis completed.")

# Calculate the average MAE and RMSE
average_mae = np.mean(mae_list)
average_rmse = np.mean(rmse_list)

# Display the final average MAE and RMSE
print(f"\nFinal Average MAE for all tickers: {average_mae}")
print(f"Final Average RMSE for all tickers: {average_rmse}")
# Out:
# Processing data for AAPL...
# [*********************100%***********************]  1 of 1 completed
# Raw data for AAPL saved to 'C:\Users\tiffa\PycharmProjects\DSE4212\dse4212-project\data\AAPL_raw_data.csv'
#
# Checking stationarity for AAPL 'Close' prices:
# ADF Test Statistic for Close: 0.6318765226267065
# ADF p-value for Close: 0.9883755371451356
# The series 'Close' is NOT stationary (p > 0.05).
#
# Checking stationarity for differenced AAPL 'Close' prices:
# ADF Test Statistic for Close_diff: -16.204331618767853
# ADF p-value for Close_diff: 4.0468893479740575e-29
# The series 'Close_diff' is stationary (p <= 0.05).
#
# Plotting ACF and PACF for differenced AAPL 'Close' prices...
# Fitting ARIMA model for AAPL with order (1, 1, 1)...
# Mean Absolute Error (MAE) for AAPL: 24.559475025862117
# Root Mean Squared Error (RMSE) for AAPL: 29.964189037399795
# Plotting ACF of residuals for AAPL...
# Processing data for MSFT...
# [*********************100%***********************]  1 of 1 completed
# Raw data for MSFT saved to 'C:\Users\tiffa\PycharmProjects\DSE4212\dse4212-project\data\MSFT_raw_data.csv'
# Checking stationarity for MSFT 'Close' prices:
# ADF Test Statistic for Close: 0.9173720591135077
# ADF p-value for Close: 0.9933128996668844
# The series 'Close' is NOT stationary (p > 0.05).
#
# Checking stationarity for differenced MSFT 'Close' prices:
# ADF Test Statistic for Close_diff: -13.73201584097268
# ADF p-value for Close_diff: 1.135470607102217e-25
# The series 'Close_diff' is stationary (p <= 0.05).
#
# Plotting ACF and PACF for differenced MSFT 'Close' prices...
# Fitting ARIMA model for MSFT with order (1, 1, 1)...
# Mean Absolute Error (MAE) for MSFT: 84.3147187702545
# Root Mean Squared Error (RMSE) for MSFT: 102.89257873026654
# Plotting ACF of residuals for MSFT...
# Processing data for GOOG...
# [*********************100%***********************]  1 of 1 completed
# Raw data for GOOG saved to 'C:\Users\tiffa\PycharmProjects\DSE4212\dse4212-project\data\GOOG_raw_data.csv'
#
# Checking stationarity for GOOG 'Close' prices:
# ADF Test Statistic for Close: 0.07973649653524863
# ADF p-value for Close: 0.9646500671307332
# The series 'Close' is NOT stationary (p > 0.05).
#
# Checking stationarity for differenced GOOG 'Close' prices:
# ADF Test Statistic for Close_diff: -13.78370566401471
# ADF p-value for Close_diff: 9.195225232771969e-26
# The series 'Close_diff' is stationary (p <= 0.05).
#
# Plotting ACF and PACF for differenced GOOG 'Close' prices...
# Fitting ARIMA model for GOOG with order (1, 1, 1)...
# Mean Absolute Error (MAE) for GOOG: 28.178682809991212
# Root Mean Squared Error (RMSE) for GOOG: 35.00493536122877
# Plotting ACF of residuals for GOOG...
# Processing data for AMZN...
# [*********************100%***********************]  1 of 1 completed
# Raw data for AMZN saved to 'C:\Users\tiffa\PycharmProjects\DSE4212\dse4212-project\data\AMZN_raw_data.csv'
#
# Checking stationarity for AMZN 'Close' prices:
# ADF Test Statistic for Close: -0.8824998037756601
# ADF p-value for Close: 0.793680843142863
# The series 'Close' is NOT stationary (p > 0.05).
#
# Checking stationarity for differenced AMZN 'Close' prices:
# ADF Test Statistic for Close_diff: -17.395706884684774
# ADF p-value for Close_diff: 4.97993061978902e-30
# The series 'Close_diff' is stationary (p <= 0.05).
#
# Plotting ACF and PACF for differenced AMZN 'Close' prices...
# Fitting ARIMA model for AMZN with order (1, 1, 1)...
# C:\Users\tiffa\PycharmProjects\DSE4212\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\tiffa\PycharmProjects\DSE4212\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Mean Absolute Error (MAE) for AMZN: 28.642248381913127
# Root Mean Squared Error (RMSE) for AMZN: 34.7148996185068
# Plotting ACF of residuals for AMZN...
# Processing data for META...
# [*********************100%***********************]  1 of 1 completed
# Raw data for META saved to 'C:\Users\tiffa\PycharmProjects\DSE4212\dse4212-project\data\META_raw_data.csv'
# Checking stationarity for META 'Close' prices:
# ADF Test Statistic for Close: 0.49952777448260494
# ADF p-value for Close: 0.9848587363230267
# The series 'Close' is NOT stationary (p > 0.05).
#
# Checking stationarity for differenced META 'Close' prices:
# ADF Test Statistic for Close_diff: -14.406435039543299
# ADF p-value for Close_diff: 8.342499171316681e-27
# The series 'Close_diff' is stationary (p <= 0.05).
#
# Plotting ACF and PACF for differenced META 'Close' prices...
# Fitting ARIMA model for META with order (1, 1, 1)...
# Mean Absolute Error (MAE) for META: 162.2016914953859
# Root Mean Squared Error (RMSE) for META: 201.51815893078162
# Plotting ACF of residuals for META...
# Processing data for NVDA...
# [*********************100%***********************]  1 of 1 completed
# Raw data for NVDA saved to 'C:\Users\tiffa\PycharmProjects\DSE4212\dse4212-project\data\NVDA_raw_data.csv'
#
# Checking stationarity for NVDA 'Close' prices:
# ADF Test Statistic for Close: 2.9292772294754075
# ADF p-value for Close: 1.0
# The series 'Close' is NOT stationary (p > 0.05).
#
# Checking stationarity for differenced NVDA 'Close' prices:
# ADF Test Statistic for Close_diff: -8.477845673271624
# ADF p-value for Close_diff: 1.419397392674612e-13
# The series 'Close_diff' is stationary (p <= 0.05).
#
# Plotting ACF and PACF for differenced NVDA 'Close' prices...
# Fitting ARIMA model for NVDA with order (1, 1, 1)...
# Mean Absolute Error (MAE) for NVDA: 37.83913198168588
# Root Mean Squared Error (RMSE) for NVDA: 51.37266447594398
# Plotting ACF of residuals for NVDA...
# Processing data for LLY...
# [*********************100%***********************]  1 of 1 completed
# Raw data for LLY saved to 'C:\Users\tiffa\PycharmProjects\DSE4212\dse4212-project\data\LLY_raw_data.csv'
#
# Checking stationarity for LLY 'Close' prices:
# ADF Test Statistic for Close: 4.9642261168808455
# ADF p-value for Close: 1.0
# The series 'Close' is NOT stationary (p > 0.05).
#
# Checking stationarity for differenced LLY 'Close' prices:
# ADF Test Statistic for Close_diff: -9.495706801855823
# ADF p-value for Close_diff: 3.553801328955641e-16
# The series 'Close_diff' is stationary (p <= 0.05).
#
# Plotting ACF and PACF for differenced LLY 'Close' prices...
# Fitting ARIMA model for LLY with order (1, 1, 1)...
# C:\Users\tiffa\PycharmProjects\DSE4212\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\tiffa\PycharmProjects\DSE4212\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Mean Absolute Error (MAE) for LLY: 252.2661712720494
# Root Mean Squared Error (RMSE) for LLY: 318.9379933655265
# Plotting ACF of residuals for LLY...
# Processing data for ABBV...
# [*********************100%***********************]  1 of 1 completed
# Raw data for ABBV saved to 'C:\Users\tiffa\PycharmProjects\DSE4212\dse4212-project\data\ABBV_raw_data.csv'
#
# Checking stationarity for ABBV 'Close' prices:
# ADF Test Statistic for Close: 0.08465729318146754
# ADF p-value for Close: 0.9649978295008649
# The series 'Close' is NOT stationary (p > 0.05).
#
# Checking stationarity for differenced ABBV 'Close' prices:
# ADF Test Statistic for Close_diff: -16.393242991289913
# ADF p-value for Close_diff: 2.6815554619774585e-29
# The series 'Close_diff' is stationary (p <= 0.05).
#
# Plotting ACF and PACF for differenced ABBV 'Close' prices...
# Fitting ARIMA model for ABBV with order (1, 1, 1)...
# Mean Absolute Error (MAE) for ABBV: 22.158013838140644
# Root Mean Squared Error (RMSE) for ABBV: 26.43283795004505
# Plotting ACF of residuals for ABBV...
# Processing data for JNJ...
# [*********************100%***********************]  1 of 1 completed
# Raw data for JNJ saved to 'C:\Users\tiffa\PycharmProjects\DSE4212\dse4212-project\data\JNJ_raw_data.csv'
#
# Checking stationarity for JNJ 'Close' prices:
# ADF Test Statistic for Close: -1.5540582758033492
# ADF p-value for Close: 0.5066204114181984
# The series 'Close' is NOT stationary (p > 0.05).
#
# Checking stationarity for differenced JNJ 'Close' prices:
# ADF Test Statistic for Close_diff: -15.39385997235264
# ADF p-value for Close_diff: 3.2826145209225913e-28
# The series 'Close_diff' is stationary (p <= 0.05).
#
# Plotting ACF and PACF for differenced JNJ 'Close' prices...
# Fitting ARIMA model for JNJ with order (1, 1, 1)...
# Mean Absolute Error (MAE) for JNJ: 6.879275298911449
# Root Mean Squared Error (RMSE) for JNJ: 8.60630280298177
# Plotting ACF of residuals for JNJ...
# Processing data for MRK...
# [*********************100%***********************]  1 of 1 completed
# Raw data for MRK saved to 'C:\Users\tiffa\PycharmProjects\DSE4212\dse4212-project\data\MRK_raw_data.csv'
#
# Checking stationarity for MRK 'Close' prices:
# ADF Test Statistic for Close: -0.33570101790365264
# ADF p-value for Close: 0.9202935967329545
# The series 'Close' is NOT stationary (p > 0.05).
#
# Checking stationarity for differenced MRK 'Close' prices:
# ADF Test Statistic for Close_diff: -15.348638016001553
# ADF p-value for Close_diff: 3.746191260998703e-28
# The series 'Close_diff' is stationary (p <= 0.05).
#
# Plotting ACF and PACF for differenced MRK 'Close' prices...
# Fitting ARIMA model for MRK with order (1, 1, 1)...
# Mean Absolute Error (MAE) for MRK: 26.659380789170314
# Root Mean Squared Error (RMSE) for MRK: 28.891645323279924
# Plotting ACF of residuals for MRK...
# Processing data for TMO...
# [*********************100%***********************]  1 of 1 completed
# Raw data for TMO saved to 'C:\Users\tiffa\PycharmProjects\DSE4212\dse4212-project\data\TMO_raw_data.csv'
# Checking stationarity for TMO 'Close' prices:
# ADF Test Statistic for Close: -0.4518320376629629
# ADF p-value for Close: 0.9010783935394396
# The series 'Close' is NOT stationary (p > 0.05).
#
# Checking stationarity for differenced TMO 'Close' prices:
# ADF Test Statistic for Close_diff: -17.456322509482177
# ADF p-value for Close_diff: 4.6231388389520874e-30
# The series 'Close_diff' is stationary (p <= 0.05).
#
# Plotting ACF and PACF for differenced TMO 'Close' prices...
# Fitting ARIMA model for TMO with order (1, 1, 1)...
# Mean Absolute Error (MAE) for TMO: 27.78460427996569
# Root Mean Squared Error (RMSE) for TMO: 35.79374587514175
# Plotting ACF of residuals for TMO...
# Processing data for UNH...
# [*********************100%***********************]  1 of 1 completed
# Raw data for UNH saved to 'C:\Users\tiffa\PycharmProjects\DSE4212\dse4212-project\data\UNH_raw_data.csv'
#
# Checking stationarity for UNH 'Close' prices:
# ADF Test Statistic for Close: -0.12436976585163988
# ADF p-value for Close: 0.9469564604508064
# The series 'Close' is NOT stationary (p > 0.05).
#
# Checking stationarity for differenced UNH 'Close' prices:
# ADF Test Statistic for Close_diff: -18.105999503203797
# ADF p-value for Close_diff: 2.5455153324797405e-30
# The series 'Close_diff' is stationary (p <= 0.05).
#
# Plotting ACF and PACF for differenced UNH 'Close' prices...
# Fitting ARIMA model for UNH with order (1, 1, 1)...
# Mean Absolute Error (MAE) for UNH: 25.404389166673695
# Root Mean Squared Error (RMSE) for UNH: 30.66017414139126
# Plotting ACF of residuals for UNH...
# Data processing, ADF testing, ACF/PACF plotting, ARIMA modeling, and residual analysis completed.
#
# Final Average MAE for all tickers: 60.573981925833664
# Final Average RMSE for all tickers: 75.39917713437448
