# %%
import yfinance as yf
import pandas as pd
import numpy as np
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
import matplotlib.pyplot as plt
import pandas_ta as ta

# List of tickers for the six companies
#tickers = ["AAPL", "MSFT", "GOOG", "AMZN", "META", "NVDA"]
tickers = ["LLY", "ABBV", "JNJ", "MRK", "TMO", "UNH"]

# Define the start and end dates
start_date = '2014-09-01'
end_date = '2024-09-01'

# Define the folder path for saving CSV files
data_folder = os.path.join(os.getcwd(), 'data')

# Create the folder if it doesn't exist
if not os.path.exists(data_folder):
    os.makedirs(data_folder)

# Function to check stationarity using ADF test and apply differencing
def make_stationary(series, name="", max_diff_order=3):
    differencing_order = 0
    while differencing_order <= max_diff_order:
        adf_result = adfuller(series)
        if adf_result[1] <= 0.05:
            return series
        elif differencing_order == max_diff_order:
            return series
        else:
            series = series.diff().dropna()
            differencing_order += 1

# Initialize lists to store RMSE and MAE for each ticker
mae_list = []
rmse_list = []

# For each ticker, process data
for ticker in tickers:
    print(f"\nProcessing data for {ticker}...")

    # Download historical stock data
    hist = yf.download(ticker, start=start_date, end=end_date)

    # Save the raw data to CSV
    raw_csv_filename = os.path.join(data_folder, f"{ticker}_raw_data.csv")
    hist.to_csv(raw_csv_filename)

    # Ensure index is a DateTimeIndex and set frequency
    hist.index = pd.to_datetime(hist.index)
    hist = hist.asfreq('B')
    hist.ffill(inplace=True)

    # Additional Exogenous Variables
    hist['5_day_SMA'] = hist['Close'].rolling(window=5).mean()
    hist['20_day_SMA'] = hist['Close'].rolling(window=20).mean()
    hist['50_day_SMA'] = hist['Close'].rolling(window=50).mean()
    hist['14_day_RSI'] = ta.rsi(hist['Close'], window=14)
    hist['Lagged_Close'] = hist['Close'].shift(1)
    hist['ATR'] = ta.atr(hist['High'], hist['Low'], hist['Close'], window=14)
    hist['Day_of_Week'] = hist.index.dayofweek
    hist['Daily_Return'] = hist['Close'].pct_change()

    # Handle NaN and Inf values in the newly created variables
    hist.replace([np.inf, -np.inf], np.nan, inplace=True)
    hist.dropna(inplace=True)

    # Apply stationarity check and differencing to exogenous variables
    hist['Open_stationary'] = make_stationary(hist['Open'], name="Open")
    hist['Low_stationary'] = make_stationary(hist['Low'], name="Low")
    hist['High_stationary'] = make_stationary(hist['High'], name="High")
    hist['Volume_stationary'] = make_stationary(hist['Volume'], name="Volume")
    hist['Close_stationary'] = make_stationary(hist['Close'], name="Close")
    hist['5_day_SMA_stationary'] = make_stationary(hist['5_day_SMA'], name="5_day_SMA")
    hist['20_day_SMA_stationary'] = make_stationary(hist['20_day_SMA'], name="20_day_SMA")
    hist['50_day_SMA_stationary'] = make_stationary(hist['50_day_SMA'], name="50_day_SMA")
    hist['14_day_RSI_stationary'] = make_stationary(hist['14_day_RSI'], name="14_day_RSI")
    hist['Lagged_Close_stationary'] = make_stationary(hist['Lagged_Close'], name="Lagged_Close")
    hist['ATR_stationary'] = make_stationary(hist['ATR'], name="ATR")

    # Generate lagged versions of exogenous variables
    exogenous_vars = ['Open_stationary', 'Low_stationary', 'High_stationary',
                      'Volume_stationary', 'Close_stationary',
                      '5_day_SMA_stationary', '20_day_SMA_stationary', '50_day_SMA_stationary',
                      '14_day_RSI_stationary', 'Lagged_Close_stationary', 'ATR_stationary', 'Day_of_Week']
    for var in exogenous_vars:
        hist[f"{var}_lag1"] = hist[var].shift(1)

    # Final dropna to ensure no NaN or Inf values remain
    hist.dropna(inplace=True)

    # Train-test split (80% train, 20% test)
    split_point = int(len(hist) * 0.8)
    train_data = hist[:split_point]
    test_data = hist[split_point:]

    # Define the endogenous and exogenous variables
    endog_train = train_data['Close']
    exog_train = train_data[[f"{var}_lag1" for var in exogenous_vars]]
    endog_test = test_data['Close']
    exog_test = test_data[[f"{var}_lag1" for var in exogenous_vars]]

    # Auto ARIMA parameter tuning for each ticker
    auto_arima_model = auto_arima(endog_train, exogenous=exog_train, seasonal=False, trace=True, error_action='ignore',
                                  suppress_warnings=True)
    best_order = auto_arima_model.order

    # Fit ARIMAX model with tuned parameters
    try:
        model = ARIMA(endog_train, order=best_order, exog=exog_train)
        arimax_result = model.fit()
    except (ValueError, np.linalg.LinAlgError, RuntimeError) as e:
        try:
            simpler_order = (1, 1, 1)
            model = ARIMA(endog_train, order=simpler_order, exog=exog_train)
            arimax_result = model.fit()
        except Exception as final_e:
            continue

    # Forecast
    forecast = arimax_result.forecast(steps=len(endog_test), exog=exog_test)

    # Plot actual vs forecasted values
    plt.figure(figsize=(10, 6))
    plt.plot(endog_test.index, test_data['Close'], label='Actual Close Prices', color='blue')
    plt.plot(endog_test.index, forecast, label='Forecasted Close Prices', color='red')
    plt.title(f'ARIMAX Forecast vs Actual for {ticker}')
    plt.legend()
    plt.show()

    # Calculate MAE and RMSE
    mae = mean_absolute_error(test_data['Close'], forecast)
    rmse = np.sqrt(mean_squared_error(test_data['Close'], forecast))
    print(f"Mean Absolute Error (MAE) for {ticker}: {mae}")
    print(f"Root Mean Squared Error (RMSE) for {ticker}: {rmse}")
    
    mae_list.append(mae)
    rmse_list.append(rmse)

    # Plot residuals and ACF of residuals
    residuals = arimax_result.resid
    plt.figure(figsize=(10, 6))
    plt.plot(residuals)
    plt.title(f'Residuals of ARIMAX model for {ticker}')
    plt.show()
    plot_acf(residuals, lags=40)
    plt.title(f'Autocorrelation of Residuals for {ticker}')
    plt.show()

# Calculate and display average MAE and RMSE
average_mae = np.mean(mae_list)
average_rmse = np.mean(rmse_list)
print(f"\nFinal Average MAE for all tickers: {average_mae}")
print(f"Final Average RMSE for all tickers: {average_rmse}")
# Out:
# Processing data for LLY...
# [*********************100%***********************]  1 of 1 completed
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=9847.752, Time=0.85 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=9847.724, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=9848.912, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=9848.941, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=9849.698, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=9850.121, Time=0.35 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 1.571 seconds
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [*********************100%***********************]  1 of 1 completed
# Processing data for ABBV...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=7541.519, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7534.805, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7535.690, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=7535.670, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=7534.011, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=7531.697, Time=0.48 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=7539.518, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=7539.522, Time=0.19 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=7537.520, Time=0.18 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=7537.518, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=7536.681, Time=0.09 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0] intercept
# Total fit time: 1.791 seconds
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [*********************100%***********************]  1 of 1 completed
# Processing data for JNJ...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=4.42 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7658.220, Time=0.22 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7646.272, Time=0.33 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=7647.145, Time=0.43 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=7656.838, Time=0.25 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=7646.173, Time=0.55 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=7647.555, Time=0.66 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=7648.039, Time=1.20 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=7646.407, Time=0.80 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=3.73 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=7644.849, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=7644.994, Time=0.06 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=7646.255, Time=0.09 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=7646.719, Time=0.15 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=7645.105, Time=0.12 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=7640.645, Time=0.47 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=7643.140, Time=0.28 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=7635.776, Time=0.62 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=7642.075, Time=0.49 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=7636.616, Time=0.55 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=7637.314, Time=0.96 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=7642.892, Time=0.28 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=7633.419, Time=1.08 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=7633.064, Time=1.09 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=7633.468, Time=1.00 sec
#  ARIMA(5,1,4)(0,0,0)[0]             : AIC=inf, Time=1.63 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : AIC=7613.687, Time=1.36 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=7635.686, Time=1.23 sec
#  ARIMA(4,1,5)(0,0,0)[0]             : AIC=7618.892, Time=1.64 sec
#  ARIMA(3,1,5)(0,0,0)[0]             : AIC=7613.252, Time=1.37 sec
#  ARIMA(2,1,5)(0,0,0)[0]             : AIC=7639.711, Time=0.53 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=7636.681, Time=0.81 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=2.43 sec
#
# Best model:  ARIMA(3,1,5)(0,0,0)[0]
# Total fit time: 30.944 seconds
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [*********************100%***********************]  1 of 1 completed
# Processing data for MRK...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5532.484, Time=1.17 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5578.960, Time=0.13 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5566.591, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5568.255, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5577.464, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5561.400, Time=0.35 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=5561.865, Time=0.30 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=5553.274, Time=1.58 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=5537.083, Time=1.58 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5562.644, Time=0.41 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=5559.577, Time=0.62 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=5551.287, Time=1.36 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=5527.816, Time=1.78 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=5527.862, Time=2.02 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=2.15 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=5549.284, Time=1.75 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=5543.834, Time=1.75 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=5527.675, Time=2.60 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=5529.230, Time=2.56 sec
#  ARIMA(4,1,5)(0,0,0)[0] intercept   : AIC=5530.492, Time=2.66 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=5529.710, Time=2.28 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=5529.242, Time=2.50 sec
#  ARIMA(5,1,5)(0,0,0)[0] intercept   : AIC=5532.946, Time=2.82 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : AIC=5527.429, Time=1.15 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=inf, Time=1.58 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=5525.419, Time=0.96 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=5527.629, Time=0.63 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=5543.509, Time=0.68 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=5527.273, Time=1.22 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=5553.047, Time=0.65 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=5540.932, Time=0.88 sec
#  ARIMA(5,1,4)(0,0,0)[0]             : AIC=5528.854, Time=1.41 sec
#
# Best model:  ARIMA(4,1,3)(0,0,0)[0]
# Total fit time: 41.838 seconds
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [*********************100%***********************]  1 of 1 completed
# Processing data for TMO...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=12862.752, Time=0.61 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=12867.261, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=12866.713, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=12866.746, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=12868.252, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=12862.192, Time=0.59 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=12868.699, Time=0.24 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.61 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=12853.738, Time=0.61 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=12855.094, Time=0.35 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=12855.703, Time=0.76 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=12850.330, Time=0.81 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=12854.163, Time=0.40 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=12852.110, Time=1.10 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=12852.262, Time=1.38 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=12856.132, Time=0.58 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=12853.238, Time=1.01 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=12852.451, Time=0.41 sec
#
# Best model:  ARIMA(1,1,4)(0,0,0)[0] intercept
# Total fit time: 9.812 seconds
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [*********************100%***********************]  1 of 1 completed
# Processing data for UNH...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=11925.193, Time=1.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=12017.618, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=12005.035, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=12007.195, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=12019.638, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=11988.936, Time=0.38 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=11990.665, Time=0.42 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=11921.391, Time=1.48 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=11974.732, Time=0.90 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=11922.467, Time=1.96 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=11916.926, Time=1.71 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=11921.097, Time=1.27 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=11907.774, Time=2.14 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=11909.764, Time=1.89 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=11909.848, Time=2.44 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=2.17 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=11924.137, Time=2.09 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=11911.764, Time=2.30 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=11919.139, Time=0.95 sec
#
# Best model:  ARIMA(4,1,3)(0,0,0)[0] intercept
# Total fit time: 23.451 seconds
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\brian\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Final Average MAE for all tickers: 59.00574008668506
# Final Average RMSE for all tickers: 73.8400697937364
