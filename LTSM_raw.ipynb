# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %% [markdown]
# # Technology Stocks

# %%
# List of Stocks
stock_tickers = ['AAPL', 'AMZN', 'GOOG', 'META', 'MSFT', 'NVDA']

# Initialise List to store RMSE and MAE values
rmse_values = []
mae_values = []

# Loop through each stock ticker
for stock_ticker in stock_tickers:
    print(f'Processing {stock_ticker}...')
    
   # Load the data with date parsing
    df = pd.read_csv(f'{stock_ticker}_processed_data.csv', parse_dates=['Date'])

    # Scaling the data
    scaler = MinMaxScaler(feature_range=(0, 1))

    scaled_data = scaler.fit_transform(df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']]) # Selecting only the wanted input features

    # Prepare the data for LSTM (Sequencing)
    look_back = 60  # No. of previous time steps to use

    X, y = [], []

    for i in range(look_back, len(scaled_data)):
        X.append(scaled_data[i - look_back : i])  # Create sequences of past data
        y.append(scaled_data[i, 3])  # Use the 'Close' price as the output, 3 being the location of 'Close'

    X, y = np.array(X), np.array(y)

    # Split the data into training and test sets
    split = int(0.8 * len(X)) # 80% Train 20% Validate

    Xtrain, Xtest = X[:split], X[split:]
    ytrain, ytest = y[:split], y[split:]

    # Getting the corresponding dates for the test set
    test_dates = df['Date'].iloc[look_back + split:].values

    # Building the LSTM model
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(Xtrain.shape[1], Xtrain.shape[2])))
    model.add(Dropout(0.2))  # Dropout layer to prevent overfitting

    model.add(LSTM(units=50, return_sequences=False))
    model.add(Dropout(0.2))

    model.add(Dense(units=1))  # Dense layer to produce the final prediction

    model.compile(optimizer='adam', loss='mean_squared_error')

    # Fitting the model
    history = model.fit(Xtrain, ytrain, epochs=50, batch_size=32, validation_data=(Xtest, ytest), verbose=1)

    # Predictions
    predicted_prices = model.predict(Xtest)

    # Inverse transformation for predicted prices
    predicted_prices_reshaped = np.zeros((predicted_prices.shape[0], scaled_data.shape[1])) # Creating 2D arrays with the same shape as scaled_data
    predicted_prices_reshaped[:, 3] = predicted_prices.flatten()  # Fill only the 'Close' prices

    predicted_prices_inverse = scaler.inverse_transform(predicted_prices_reshaped)[:, 3]  # Get only the 'Close' prices

    # Inverse transformation for actual prices
    ytest_reshaped = np.zeros((ytest.shape[0], scaled_data.shape[1]))  # Creating 2D arrays with the same shape as scaled_data
    ytest_reshaped[:, 3] = ytest.flatten()  # Fill only the 'Close' prices

    actual_prices_inverse = scaler.inverse_transform(ytest_reshaped)[:, 3]  # Get only the 'Close' prices

    # Plotting the comparison of actual close prices with predicted close prices
    plt.figure(figsize=(14, 5))
    plt.plot(test_dates, actual_prices_inverse, color='blue', label='Actual Prices')
    plt.plot(test_dates, predicted_prices_inverse, color='red', label='Predicted Prices')
    plt.xlabel('Date')
    plt.ylabel('Stock Price')
    plt.title(f'{stock_ticker} Stock Price Prediction')
    plt.legend()
    plt.show()

    # Calculating the RMSE and MAE
    rmse = np.sqrt(mean_squared_error(actual_prices_inverse, predicted_prices_inverse))
    mae = mean_absolute_error(actual_prices_inverse, predicted_prices_inverse)

    print(f'{stock_ticker}_RMSE: {rmse}')
    print(f'{stock_ticker}_MAE: {mae}')

    # Append into the list for later mean calculation
    rmse_values.append(rmse)
    mae_values.append(mae)

# Calculating the mean RMSE and MAE across All stocks
mean_rmse = np.mean(rmse_values)
mean_mae = np.mean(mae_values)

print(f'Mean RMSE across Technology stocks: {mean_rmse}')
print(f'Mean MAE across Technology stocks: {mean_mae}')
# Out:
# Processing AAPL...
# Epoch 1/50
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss:
50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 7.0017e-05 - val_loss: 0.0033
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.0892e-05 - val_loss: 0.0044
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 6.1424e-05 - val_loss: 0.0065
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 6.0671e-05 - val_loss: 0.0035
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 6.2272e-05 - val_loss: 0.0017
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 6.6307e-05 - val_loss: 0.0026
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 6.2258e-05 - val_loss: 0.0025
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.9668e-05 - val_loss: 0.0030
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.3303e-05 - val_loss: 0.0026
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 6.1458e-05 - val_loss: 0.0034
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 5.0967e-05 - val_loss: 0.0033
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.8860e-05 - val_loss: 0.0023
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.7364e-05 - val_loss: 0.0030
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.5705e-05 - val_loss: 0.0042
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.2861e-05 - val_loss: 0.0035
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.7564e-05 - val_loss: 0.0017
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.7024e-05 - val_loss: 0.0033
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.9170e-05 - val_loss: 0.0047
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.6536e-05 - val_loss: 0.0014
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.9205e-05 - val_loss: 0.0020
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.3833e-05 - val_loss: 0.0028
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.6129e-05 - val_loss: 0.0032
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.4657e-05 - val_loss: 0.0023
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.4910e-05 - val_loss: 0.0019
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.3914e-05 - val_loss: 0.0022
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.6756e-05 - val_loss: 0.0014
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.0755e-05 - val_loss: 0.0031
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.7556e-05 - val_loss: 0.0020
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.7464e-05 - val_loss: 0.0020
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.6783e-05 - val_loss: 8.6190e-04
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.5126e-05 - val_loss: 0.0035
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.6918e-05 - val_loss: 0.0019
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.1770e-05 - val_loss: 0.0025
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.8568e-05 - val_loss: 5.6427e-04
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.9382e-05 - val_loss: 0.0015
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.6320e-05 - val_loss: 0.0018
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.8996e-05 - val_loss: 0.0022
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.8206e-05 - val_loss: 0.0016
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.3312e-05 - val_loss: 0.0021
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.8999e-05 - val_loss: 8.1559e-04
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.4756e-05 - val_loss: 0.0017
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# NVDA_RMSE: 5.553492773216749
# NVDA_MAE: 3.345222406735465
# Mean RMSE across Technology stocks: 6.776298692481852
# Mean MAE across Technology stocks: 5.01344625028835

# %% [markdown]
# # Healthcare Stocks

# %%
# List of Stocks
stock_tickers = ['ABBV', 'JNJ', 'LLY', 'MRK', 'TMO', 'UNH']

# Initialise List to store RMSE and MAE values
rmse_values = []
mae_values = []

# Loop through each stock ticker
for stock_ticker in stock_tickers:
    print(f'Processing {stock_ticker}...')
    
   # Load the data with date parsing
    df = pd.read_csv(f'{stock_ticker}_processed_data.csv', parse_dates=['Date'])

    # Scaling the data
    scaler = MinMaxScaler(feature_range=(0, 1))

    scaled_data = scaler.fit_transform(df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']]) # Selecting only the wanted input features

    # Prepare the data for LSTM (Sequencing)
    look_back = 60  # No. of previous time steps to use

    X, y = [], []

    for i in range(look_back, len(scaled_data)):
        X.append(scaled_data[i - look_back : i])  # Create sequences of past data
        y.append(scaled_data[i, 3])  # Use the 'Close' price as the output, 3 being the location of 'Close'

    X, y = np.array(X), np.array(y)

    # Split the data into training and test sets
    split = int(0.8 * len(X)) # 80% Train 20% Validate

    Xtrain, Xtest = X[:split], X[split:]
    ytrain, ytest = y[:split], y[split:]

    # Getting the corresponding dates for the test set
    test_dates = df['Date'].iloc[look_back + split:].values

    # Building the LSTM model
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(Xtrain.shape[1], Xtrain.shape[2])))
    model.add(Dropout(0.2))  # Dropout layer to prevent overfitting

    model.add(LSTM(units=50, return_sequences=False))
    model.add(Dropout(0.2))

    model.add(Dense(units=1))  # Dense layer to produce the final prediction

    model.compile(optimizer='adam', loss='mean_squared_error')

    # Fitting the model
    history = model.fit(Xtrain, ytrain, epochs=50, batch_size=32, validation_data=(Xtest, ytest), verbose=1)

    # Predictions
    predicted_prices = model.predict(Xtest)

    # Inverse transformation for predicted prices
    predicted_prices_reshaped = np.zeros((predicted_prices.shape[0], scaled_data.shape[1])) # Creating 2D arrays with the same shape as scaled_data
    predicted_prices_reshaped[:, 3] = predicted_prices.flatten()  # Fill only the 'Close' prices

    predicted_prices_inverse = scaler.inverse_transform(predicted_prices_reshaped)[:, 3]  # Get only the 'Close' prices

    # Inverse transformation for actual prices
    ytest_reshaped = np.zeros((ytest.shape[0], scaled_data.shape[1]))  # Creating 2D arrays with the same shape as scaled_data
    ytest_reshaped[:, 3] = ytest.flatten()  # Fill only the 'Close' prices

    actual_prices_inverse = scaler.inverse_transform(ytest_reshaped)[:, 3]  # Get only the 'Close' prices

    # Plotting the comparison of actual close prices with predicted close prices
    plt.figure(figsize=(14, 5))
    plt.plot(test_dates, actual_prices_inverse, color='blue', label='Actual Prices')
    plt.plot(test_dates, predicted_prices_inverse, color='red', label='Predicted Prices')
    plt.xlabel('Date')
    plt.ylabel('Stock Price')
    plt.title(f'{stock_ticker} Stock Price Prediction')
    plt.legend()
    plt.show()

    # Calculating the RMSE and MAE
    rmse = np.sqrt(mean_squared_error(actual_prices_inverse, predicted_prices_inverse))
    mae = mean_absolute_error(actual_prices_inverse, predicted_prices_inverse)

    print(f'{stock_ticker}_RMSE: {rmse}')
    print(f'{stock_ticker}_MAE: {mae}')

    # Append into the list for later mean calculation
    rmse_values.append(rmse)
    mae_values.append(mae)

# Calculating the mean RMSE and MAE across All stocks
mean_rmse = np.mean(rmse_values)
mean_mae = np.mean(mae_values)

print(f'Mean RMSE across Healthcare stocks: {mean_rmse}')
print(f'Mean MAE across Healthcare stocks: {mean_mae}')
# Out:
# Processing ABBV...
# Epoch 1/50
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0151 - val_loss: 0.0035
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0017 - val_loss: 9.5061e-04
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0013 - val_loss: 9.4272e-04
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0013 - val_loss: 8.9284e-04
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch
50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0032 - val_loss: 0.0050
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0013 - val_loss: 9.8457e-04
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0014 - val_loss: 0.0011
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# JNJ_RMSE: 3.1547451001239835
# JNJ_MAE: 2.539700507748407
# Processing LLY...
# Epoch 1/50
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.0139e-04 - val_loss: 0.0082
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.7245e-04 - val_loss: 0.0052
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.3273e-04 - val_loss: 0.0034
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.5051e-04 - val_loss: 0.0039
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.4567e-04 - val_loss: 0.0051
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.3294e-04 - val_loss: 0.0024
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.2350e-04 - val_loss: 0.0056
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.2195e-04 - val_loss: 0.0050
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.0518e-04 - val_loss: 0.0023
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.1519e-04 - val_loss: 0.0015
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.2422e-04 - val_loss: 0.0025
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.0077e-04 - val_loss: 0.0042
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.0333e-04 - val_loss: 0.0031
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.0848e-04 - val_loss: 0.0021
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 8.2322e-05 - val_loss: 0.0030
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 8.9645e-05 - val_loss: 0.0013
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 9.7792e-05 - val_loss: 0.0026
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 8.1872e-05 - val_loss: 0.0032
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.2145e-05 - val_loss: 0.0049
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.3299e-05 - val_loss: 0.0012
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 7.6943e-05 - val_loss: 0.0034
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.3128e-05 - val_loss: 0.0013
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.0038e-04 - val_loss: 0.0020
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 7.9054e-05 - val_loss: 0.0013
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.8539e-05 - val_loss: 0.0014
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.6957e-05 - val_loss: 0.0028
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.8801e-05 - val_loss: 0.0015
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.5915e-05 - val_loss: 8.3639e-04
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss:
50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.5965e-04 - val_loss: 0.0028
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.5863e-04 - val_loss: 0.0022
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.4378e-04 - val_loss: 0.0029
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.3066e-04 - val_loss: 0.0026
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.7614e-04 - val_loss: 0.0017
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.1059e-04 - val_loss: 0.0010
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.6775e-04 - val_loss: 0.0010
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.6605e-04 - val_loss: 0.0030
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.9868e-04 - val_loss: 0.0026
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.5803e-04 - val_loss: 0.0014
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.8345e-04 - val_loss: 0.0022
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.9083e-04 - val_loss: 4.4654e-04
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.8588e-04 - val_loss: 8.1418e-04
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.3631e-04 - val_loss: 7.4902e-04
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.7827e-04 - val_loss: 9.7698e-04
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.9663e-04 - val_loss: 0.0011
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.2979e-04 - val_loss: 0.0020
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# MRK_RMSE: 3.8497942063373425
# MRK_MAE: 3.3788730651088072
# Processing TMO...
# Epoch 1/50
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0284 - val_loss: 0.0014
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0021 - val_loss: 9.7711e-04
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0017 - val_loss: 9.9795e-04
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0017 - val_loss: 8.9909e-04
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0013 - val_loss: 8.7910e-04
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0014 - val_loss: 8.4364e-04
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0012 - val_loss: 7.5048e-04
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0012 - val_loss: 7.2900e-04
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0011 - val_loss: 8.2235e-04
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0011 - val_loss: 9.2337e-04
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0014 - val_loss: 9.5097e-04
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0013 - val_loss: 7.2574e-04
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 9.9820e-04 - val_loss: 0.0023
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0010 - val_loss: 6.5613e-04
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0010 - val_loss: 6.5496e-04
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0010 - val_loss: 6.8153e-04
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0010 - val_loss: 9.0650e-04
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.4286e-04 - val_loss: 0.0012
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.8838e-04 - val_loss: 0.0015
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.5499e-04 - val_loss: 7.6290e-04
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 9.3359e-04 - val_loss: 0.0015
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 9.4429e-04 - val_loss: 6.3121e-04
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.3402e-04 - val_loss: 8.8418e-04
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 9.2396e-04 - val_loss: 6.0944e-04
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 9.9600e-04 - val_loss: 0.0012
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0011 - val_loss: 6.1181e-04
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.8167e-04 - val_loss: 0.0013
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0010 - val_loss: 7.3297e-04
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0010 - val_loss: 5.9286e-04
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.3057e-04 - val_loss: 7.6548e-04
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.9967e-04 - val_loss: 0.0011
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.5038e-04 - val_loss: 0.0015
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# TMO_RMSE: 21.90250256974732
# TMO_MAE: 18.454747992875436
# Processing UNH...
# Epoch 1/50
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0199 - val_loss: 0.0037
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0031 - val_loss: 9.3969e-04
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0019 - val_loss: 9.5055e-04
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0015 - val_loss: 8.7032e-04
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0012 - val_loss: 9.6058e-04
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0014 - val_loss: 9.5703e-04
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0010 - val_loss: 8.0139e-04
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0011 - val_loss: 6.7326e-04
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 9.3547e-04 - val_loss: 7.1122e-04
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 9.0088e-04 - val_loss: 6.9048e-04
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 9.3176e-04 - val_loss: 8.7937e-04
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 9.4342e-04 - val_loss: 9.6383e-04
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.5512e-04 - val_loss: 6.8569e-04
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.6675e-04 - val_loss: 6.1948e-04
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.9185e-04 - val_loss: 0.0018
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 9.4809e-04 - val_loss: 6.0405e-04
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.4878e-04 - val_loss: 8.1152e-04
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0010 - val_loss: 6.1467e-04
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.4467e-04 - val_loss: 0.0021
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.3303e-04 - val_loss: 8.9458e-04
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.8321e-04 - val_loss: 6.3937e-04
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 6.7282e-04 - val_loss: 6.0353e-04
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.0281e-04 - val_loss: 0.0011
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.4091e-04 - val_loss: 6.9543e-04
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.6592e-04 - val_loss: 7.3539e-04
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.3820e-04 - val_loss: 0.0012
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.0077e-04 - val_loss: 6.2133e-04
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 7.1468e-04 - val_loss: 5.3180e-04
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.3598e-04 - val_loss: 0.0011
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.6727e-04 - val_loss: 0.0013
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.9108e-04 - val_loss: 6.1917e-04
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 7.4283e-04 - val_loss: 5.3085e-04
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.4662e-04 - val_loss: 0.0013
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 6.9821e-04 - val_loss: 4.9240e-04
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 6.3972e-04 - val_loss: 6.9623e-04
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.6469e-04 - val_loss: 5.1938e-04
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# UNH_RMSE: 11.609370358815939
# UNH_MAE: 8.721562434503403
# Mean RMSE across Healthcare stocks: 12.49879652361693
# Mean MAE across Healthcare stocks: 9.54289105158473
